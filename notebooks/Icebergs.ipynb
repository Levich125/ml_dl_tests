# %% [markdown]
# ## Iceberg/ship detection
# dataset https://www.kaggle.com/c/statoil-iceberg-classifier-challenge

# %%
import json, sys, random
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
train_file = open('datasets/icebergs/train.json')
dataset = json.load(train_file)
train_file.close()
print(dataset[0].keys())
# Out:
# dict_keys(['is_iceberg', 'band_2', 'id', 'inc_angle', 'band_1'])

# %%
# no idea is inc_angle useful. Seems like it is distribution is narrow. Leave it out
inc = np.array([float(x['inc_angle']) for x in dataset if x['inc_angle'] != 'na'])
inc.mean(), inc.std()
# Out:
# (39.26870747790618, 3.8384390421193935)

# %%
# using minmax scaling for 'images'. Standard scaling yields strange green-red-whatever spots
x1 = []
x2 = []
labels = []
for item in dataset:
    b1 = np.array(item["band_1"]).astype(np.float32).reshape(75, 75, 1)
    b1_mx = b1.max()
    b1_mn = b1.min()
    b1 = (b1 - b1_mn)/(b1_mx - b1_mn)
    # b1 -= b1.mean()
    # b1 /= b1.std()
    x1.append(b1)
    
    b2 = np.array(item["band_2"]).astype(np.float32).reshape(75, 75, 1)
    b2_mx = b2.max()
    b2_mn = b2.min()
    b2 = (b2 - b2_mn)/(b2_mx - b2_mn)
    x2.append(b2)
    
    labels.append(item['is_iceberg'])
    
X_band1 = np.array(x1)
X_band2 = np.array(x2)
labels = np.array(labels)

# %%
# approx equal count of ships and icebergs
np.bincount(labels)
# Out:
# array([851, 753])

# %%
X_band1.shape
# Out:
# (1604, 75, 75, 1)

# %%
num = 201
# plt.imshow(X_band1[num, :, :, 0], cmap='gray')
plt.imshow(X_band2[num, :, :, 0], cmap='gray')
print(labels[num])
# Out:
# 1

# %%
# make it 3-dimensional for convenience
images = np.concatenate([X_band1, X_band2, (X_band1+X_band2)/2], axis = 3)
images.shape
# Out:
# (1604, 75, 75, 3)

# %%
num = 105
plt.imshow(images[num, :, :])
print(labels[num])
# Out:
# 0

# %%
from sklearn.model_selection import train_test_split

# %%
# test will be used in the very end - to make sure val_loss won't differ significantly
X_train, X_test, y_train, y_test = train_test_split(images, labels, stratify=labels, test_size=0.3)

# %%
X_train.shape, X_test.shape
# Out:
# ((1122, 75, 75, 3), (482, 75, 75, 3))

# %%
# enlarge training dataset - horisontal/vertical flip for all images and 90deg rotation. x6 images in total
X_train_v = X_train[:, ::-1, :, :]
X_train_h = X_train[:, :, ::-1, :]
X_train = np.vstack((X_train, X_train_v, X_train_h))


X_train_t = np.transpose(X_train, (0, 2, 1, 3))
X_train = np.vstack((X_train, X_train_t))

# %%
X_train.shape
# Out:
# (6732, 75, 75, 3)

# %%
y_train = np.concatenate([y_train] * 6)
y_train.shape
# Out:
# (6732,)

# %%
from tensorflow.keras import layers, models, callbacks
from sklearn.metrics import log_loss

# %%
model = models.Sequential()

model.add(layers.Conv2D(32, input_shape=(75, 75, 3), activation='relu', kernel_size=(3, 3), padding='same'))
model.add(layers.MaxPooling2D(2,2))
model.add(layers.BatchNormalization(axis = -1))
model.add(layers.Dropout(0.2))

for flt in [32, 64, 64, 64]:
    model.add(layers.Conv2D(flt, activation='relu', kernel_size=(3, 3), padding='same'))
    model.add(layers.MaxPooling2D(2,2))
    model.add(layers.BatchNormalization(axis = -1))
    model.add(layers.Dropout(0.2))
    
model.add(layers.Flatten())
model.add(layers.Dense(512, activation = 'relu'))
model.add(layers.BatchNormalization())
model.add(layers.Dropout(0.5))

model.add(layers.Dense(32, activation = 'relu'))
model.add(layers.BatchNormalization())
model.add(layers.Dropout(0.5))

model.add(layers.Dense(1, activation = 'sigmoid'))

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['acc'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_5 (Conv2D)            (None, 75, 75, 32)        896
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 37, 37, 32)        0
# _________________________________________________________________
# batch_normalization_v2_7 (Ba (None, 37, 37, 32)        128
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 37, 37, 32)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 37, 37, 32)        9248
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 18, 18, 32)        0
# _________________________________________________________________
# batch_normalization_v2_8 (Ba (None, 18, 18, 32)        128
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 18, 18, 32)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 18, 18, 64)        18496
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 9, 9, 64)          0
# _________________________________________________________________
# batch_normalization_v2_9 (Ba (None, 9, 9, 64)          256
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 9, 9, 64)          0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 9, 9, 64)          36928
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 4, 4, 64)          0
# _________________________________________________________________
# batch_normalization_v2_10 (B (None, 4, 4, 64)          256
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 4, 4, 64)          0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 4, 4, 64)          36928
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 2, 2, 64)          0
# _________________________________________________________________
# batch_normalization_v2_11 (B (None, 2, 2, 64)          256
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 2, 2, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 256)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 512)               131584
# _________________________________________________________________
# batch_normalization_v2_12 (B (None, 512)               2048
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 32)                16416
# _________________________________________________________________
# batch_normalization_v2_13 (B (None, 32)                128
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 32)                0
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 253,729
# Trainable params: 252,129
# Non-trainable params: 1,600
# _________________________________________________________________

# %%
# stop if val_loss won't become better in 20 epochs, save the best model in terms of val_loss
es = callbacks.EarlyStopping('val_loss', patience=20, mode="min")
best_model = callbacks.ModelCheckpoint('saved_models/icebergs.hdf5', save_best_only=True, monitor='val_loss')

cb = [es, best_model]

# %%
history = model.fit(X_train, y_train, epochs=200, validation_split=0.2, batch_size=128, callbacks=cb) # validation_data=(X_test, y_test)
# Out:
# Train on 5385 samples, validate on 1347 samples
# Epoch 1/200
# 5385/5385 [==============================] - 3s 554us/sample - loss: 0.6823 - acc: 0.6611 - val_loss: 0.6930 - val_acc: 0.5308
# Epoch 2/200
# 5385/5385 [==============================] - 2s 348us/sample - loss: 0.5290 - acc: 0.7385 - val_loss: 0.7434 - val_acc: 0.5308
# Epoch 3/200
# 5385/5385 [==============================] - 2s 349us/sample - loss: 0.4547 - acc: 0.7690 - val_loss: 0.8058 - val_acc: 0.5308
# Epoch 4/200
# 5385/5385 [==============================] - 2s 350us/sample - loss: 0.4125 - acc: 0.7929 - val_loss: 0.8585 - val_acc: 0.5308
# Epoch 5/200
# 5385/5385 [==============================] - 2s 351us/sample - loss: 0.3860 - acc: 0.8150 - val_loss: 0.7704 - val_acc: 0.5308
# Epoch 6/200
# 5385/5385 [==============================] - 2s 350us/sample - loss: 0.3710 - acc: 0.8193 - val_loss: 0.9041 - val_acc: 0.5308
# Epoch 7/200
# 5385/5385 [==============================] - 2s 350us/sample - loss: 0.3453 - acc: 0.8282 - val_loss: 0.8127 - val_acc: 0.5271
# Epoch 8/200
# 5385/5385 [==============================] - 2s 350us/sample - loss: 0.3298 - acc: 0.8396 - val_loss: 0.7348 - val_acc: 0.5531
# Epoch 9/200
# 5385/5385 [==============================] - 2s 398us/sample - loss: 0.3387 - acc: 0.8336 - val_loss: 0.6852 - val_acc: 0.6385
# Epoch 10/200
# 5385/5385 [==============================] - 2s 351us/sample - loss: 0.3205 - acc: 0.8457 - val_loss: 0.7764 - val_acc: 0.6125
# Epoch 11/200
# 5385/5385 [==============================] - 2s 350us/sample - loss: 0.3166 - acc: 0.8524 - val_loss: 0.7694 - val_acc: 0.5872
# Epoch 12/200
# 5385/5385 [==============================] - 2s 362us/sample - loss: 0.3555 - acc: 0.8336 - val_loss: 0.6608 - val_acc: 0.6941
# Epoch 13/200
# 5385/5385 [==============================] - 2s 351us/sample - loss: 0.3312 - acc: 0.8392 - val_loss: 0.9370 - val_acc: 0.6793
# Epoch 14/200
# 5385/5385 [==============================] - 2s 350us/sample - loss: 0.3064 - acc: 0.8516 - val_loss: 0.9784 - val_acc: 0.6815
# Epoch 15/200
# 5385/5385 [==============================] - 2s 350us/sample - loss: 0.2977 - acc: 0.8583 - val_loss: 0.7725 - val_acc: 0.7030
# Epoch 16/200
# 5385/5385 [==============================] - 2s 350us/sample - loss: 0.2929 - acc: 0.8501 - val_loss: 0.7282 - val_acc: 0.6867
# Epoch 17/200
# 5385/5385 [==============================] - 2s 363us/sample - loss: 0.2895 - acc: 0.8656 - val_loss: 0.4064 - val_acc: 0.7929
# Epoch 18/200
# 5385/5385 [==============================] - 2s 350us/sample - loss: 0.2785 - acc: 0.8670 - val_loss: 0.7481 - val_acc: 0.6763
# Epoch 19/200
# 5385/5385 [==============================] - 2s 350us/sample - loss: 0.2668 - acc: 0.8709 - val_loss: 0.4877 - val_acc: 0.7602
# Epoch 20/200
# 5385/5385 [==============================] - 2s 350us/sample - loss: 0.
200
# 5385/5385 [==============================] - 2s 351us/sample - loss: 0.1835 - acc: 0.9233 - val_loss: 0.6397 - val_acc: 0.7387
# Epoch 51/200
# 5385/5385 [==============================] - 2s 361us/sample - loss: 0.1850 - acc: 0.9213 - val_loss: 0.2546 - val_acc: 0.8834
# Epoch 52/200
# 5385/5385 [==============================] - 2s 351us/sample - loss: 0.1704 - acc: 0.9274 - val_loss: 0.2883 - val_acc: 0.8842
# Epoch 53/200
# 5385/5385 [==============================] - 2s 351us/sample - loss: 0.1882 - acc: 0.9218 - val_loss: 0.3047 - val_acc: 0.8619
# Epoch 54/200
# 5385/5385 [==============================] - 2s 351us/sample - loss: 0.1827 - acc: 0.9261 - val_loss: 0.5136 - val_acc: 0.8448
# Epoch 55/200
# 5385/5385 [==============================] - 2s 351us/sample - loss: 0.2108 - acc: 0.9099 - val_loss: 0.4045 - val_acc: 0.8285
# Epoch 56/200
# 5385/5385 [==============================] - 2s 361us/sample - loss: 0.1653 - acc: 0.9309 - val_loss: 0.2363 - val_acc: 0.8946
# Epoch 57/200
# 5385/5385 [==============================] - 2s 351us/sample - loss: 0.1624 - acc: 0.9322 - val_loss: 1.2353 - val_acc: 0.6466
# Epoch 58/200
# 5385/5385 [==============================] - 2s 351us/sample - loss: 0.1564 - acc: 0.9357 - val_loss: 0.2657 - val_acc: 0.8834
# Epoch 59/200
# 5385/5385 [==============================] - 2s 351us/sample - loss: 0.1950 - acc: 0.9198 - val_loss: 0.5789 - val_acc: 0.7981
# Epoch 60/200
# 5385/5385 [==============================] - 2s 351us/sample - loss: 0.1564 - acc: 0.9369 - val_loss: 0.2804 - val_acc: 0.8894
# Epoch 61/200
# 5385/5385 [==============================] - 2s 352us/sample - loss: 0.1535 - acc: 0.9385 - val_loss: 0.2583 - val_acc: 0.8946
# Epoch 62/200
# 5385/5385 [==============================] - 2s 350us/sample - loss: 0.1631 - acc: 0.9346 - val_loss: 0.4341 - val_acc: 0.8500
# Epoch 63/200
# 5385/5385 [==============================] - 2s 351us/sample - loss: 0.1406 - acc: 0.9430 - val_loss: 0.5575 - val_acc: 0.8107
# Epoch 64/200
# 5385/5385 [==============================] - 2s 350us/sample - loss: 0.1401 - acc: 0.9460 - val_loss: 0.3739 - val_acc: 0.8530
# Epoch 65/200
# 5385/5385 [==============================] - 2s 350us/sample - loss: 0.1220 - acc: 0.9523 - val_loss: 0.4074 - val_acc: 0.8760
# Epoch 66/200
# 5385/5385 [==============================] - 2s 351us/sample - loss: 0.1291 - acc: 0.9489 - val_loss: 0.3061 - val_acc: 0.8842
# Epoch 67/200
# 5385/5385 [==============================] - 2s 351us/sample - loss: 0.1927 - acc: 0.9177 - val_loss: 0.2874 - val_acc: 0.8797
# Epoch 68/200
# 5385/5385 [==============================] - 2s 352us/sample - loss: 0.1528 - acc: 0.9393 - val_loss: 0.5768 - val_acc: 0.7944
# Epoch 69/200
# 5385/5385 [==============================] - 2s 350us/sample - loss: 0.1419 - acc: 0.9428 - val_loss: 0.2665 - val_acc: 0.8946
# Epoch 70/200
# 5385/5385 [==============================] - 2s 350us/sample - loss: 0.1332 - acc: 0.9510 - val_loss: 0.3316 - val_acc: 0.8797
# Epoch 71/200
# 5385/5385 [==============================] - 2s 351us/sample - loss: 0.1300 - acc: 0.9523 - val_loss: 0.5737 - val_acc: 0.7817
# Epoch 72/200
# 5385/5385 [==============================] - 2s 351us/sample - loss: 0.1709 - acc: 0.9307 - val_loss: 0.3059 - val_acc: 0.8738
# Epoch 73/200
# 5385/5385 [==============================] - 2s 350us/sample - loss: 0.1479 - acc: 0.9430 - val_loss: 0.2785 - val_acc: 0.8775
# Epoch 74/200
# 5385/5385 [==============================] - 2s 351us/sample - loss: 0.1358 - acc: 0.9480 - val_loss: 0.2462 - val_acc: 0.8990
# Epoch 75/200
# 5385/5385 [==============================] - 2s 350us/sample - loss: 0.1256 - acc: 0.9500 - val_loss: 0.3249 - val_acc: 0.8656
# Epoch 76/200
# 5385/5385 [==============================] - 2s 352us/sample - loss: 0.1242 - acc: 0.9515 - val_loss: 0.4365 - val_acc: 0.8560

# %%
# well, test loss is similar to the best val loss. Not great, not terrible.
model.load_weights('saved_models/icebergs.hdf5')
model.evaluate(X_test, y_test)
# Out:
# 482/482 [==============================] - 1s 2ms/sample - loss: 0.1636 - acc: 0.9357
# [0.16358055845212144, 0.9356846]

# %%
print(y_test[50])
model.predict(X_test[50:51])
# Out:
# 1
# array([[0.9176329]], dtype=float32)

# %%
plt.imshow(X_test[50, :, :])

# %%
print(y_test[50])
# Out:
# 1
